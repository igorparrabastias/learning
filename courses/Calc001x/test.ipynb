# %%
import sympy as sp
sp.init_printing()

# %%
f=(x**3-4)**2-x**6+2*x**5
sp.simplify(f)
# Out:
# 2*x**5 - 8*x**3 + 16

# %%
f=(3*x**6-11*x+2)/(6*x)

# %%
sp.simplify(f)
# Out:
# (3*x**6 - 11*x + 2)/(6*x)

# %%
f
# Out:
# 1/6*(3*x^6 - 11*x + 2)/x

# %%
sp.plot(f)

# %%
f(x)=(5*x^2-2)^3-1/2*x^3

# %%
f
# Out:
# x |--> (5*x^2 - 2)^3 - 1/2*x^3

# %%
sp.expand(f)
# Out:
# 125*x**6 - 150*x**4 - x**3/2 + 60*x**2 - 8

# %%
sp.expand((1-2*x)^3)
# Out:
# -8*x**3 + 12*x**2 - 6*x + 1

# %%
sp.expand(-3*(x+4)*(x-2)+2*(3*x-1))
# Out:
# 22 - 3*x**2

# %%
sp.expand(((2*x+1)^2)*(x-1)-x*(4*x^2-1))
# Out:
# -2*x - 1

# %%
y=x^2+500000

# %%
sp.plot(y)
