# %%
from sympy import solve, symbols, plot, simplify

# %%
f = (x-h)**2 + k - (x**2-4*x+7)

# %%
x, h, k = symbols('x h k')
solve( f, [h,k] )
# Out:
# [(2, 3)]

# %%
f2 = ((x-2)**2 + 3).expand()

# %%
    plot(f2, (x, -3, 3))

# %%
plot(f2)

# %%
x, r, s = symbols('x r s', real=True)

# %%
f3 = x**12 + 6*x + 13 - ((x - r)**2 + s)
solve( f3, [r,s] )
# Out:
# [(r, x**12 + 6*x - (r - x)**2 + 13)]

# %%
plot(x**2-4*x+7)

# %%
plot(x**2-20)

# %%
plot(3*x**2+9*x-30)

# %%
simplify(42/100)
# Out:
# 0.420000000000000

# %%
plot(x**3)
